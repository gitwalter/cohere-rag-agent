# %% [markdown]
# # Finviz API
#
#
# https://finvizfinance.readthedocs.io/en/latest/

# %% [markdown]
# # Setup

# %%
# ! pip install finvizfinance

# %% [markdown]
# # Imports and Functions

# %%
import pandas as pd
from IPython.display import Image
from finvizfinance.quote import finvizfinance


# Function to convert dictionary to HTML table
def dict_to_html_table(d):
    html = '<table>'
    for key, value in d.items():
        html += f'<tr><td><b>{key}</b></td><td>{value}</td></tr>'
    html += '</table>'
    return html

# %% [markdown]
# # Set Ticker Symbols

# %%
ticker_to_analyze = 'MSFT'
tickers_to_analyze = ["MSFT", "GOOG", "AMSC", "BSX", "SE", "RTX", "MA", "PLTR", "UBER", "URI"]

# %% [markdown]
# # Display Charts

# %%
# Create a stock object for MSFT
stock = finvizfinance(ticker_to_analyze)

# Define timeframes
tf_monthly = "monthly"
tf_weekly = "weekly"
tf_daily = "daily"

# Get the URLs of the stock charts for different timeframes
chart_url_monthly = stock.ticker_charts(urlonly=True, timeframe=tf_monthly)
chart_url_weekly = stock.ticker_charts(urlonly=True, timeframe=tf_weekly)
chart_url_daily = stock.ticker_charts(urlonly=True, timeframe=tf_daily)

# Display the images inside the Jupyter Notebook
display(Image(url=chart_url_monthly), Image(url=chart_url_weekly), Image(url=chart_url_daily))
# Out:
# <img src="https://finviz.com/chart.ashx?t=MSFT&ty=c&ta=0&p=m"/>
# <img src="https://finviz.com/chart.ashx?t=MSFT&ty=c&ta=0&p=w"/>
# <img src="https://finviz.com/chart.ashx?t=MSFT&ty=c&ta=1&p=d"/>

# %% [markdown]
# # Fundamental Data

# %% [markdown]
# ## Display Dictionary as HTML Table

# %%
# stock_full_info = stock.ticker_full_info()
stock_fundament = stock.ticker_fundament()
# Convert dictionary to HTML table
html_table_fundament = dict_to_html_table(stock_fundament)
# Display the HTML table
display(HTML(html_table_fundament))
# Out:
# <table><tr><td><b>Company</b></td><td>Microsoft Corporation</td></tr><tr><td><b>Sector</b></td><td>Technology</td></tr><tr><td><b>Industry</b></td><td>Software - Infrastructure</td></tr><tr><td><b>Country</b></td><td>USA</td></tr><tr><td><b>Exchange</b></td><td>NASD</td></tr><tr><td><b>Index</b></td><td>DJIA, NDX, S&P 500</td></tr><tr><td><b>P/E</b></td><td>36.74</td></tr><tr><td><b>EPS (ttm)</b></td><td>11.54</td></tr><tr><td><b>Insider Own</b></td><td>1.47%</td></tr><tr><td><b>Shs Outstand</b></td><td>7.43B</td></tr><tr><td><b>Perf Week</b></td><td>-1.20%</td></tr><tr><td><b>Market Cap</b></td><td>3151.37B</td></tr><tr><td><b>Forward P/E</b></td><td>31.76</td></tr><tr><td><b>EPS next Y</b></td><td>13.35</td></tr><tr><td><b>Insider Trans</b></td><td>-0.12%</td></tr><tr><td><b>Shs Float</b></td><td>7.32B</td></tr><tr><td><b>Perf Month</b></td><td>2.53%</td></tr><tr><td><b>Income</b></td><td>86.18B</td></tr><tr><td><b>PEG</b></td><td>2.26</td></tr><tr><td><b>EPS next Q</b></td><td>2.93</td></tr><tr><td><b>Inst Own</b></td><td>72.92%</td></tr><tr><td><b>Short Float</b></td><td>0.60%</td></tr><tr><td><b>Perf Quarter</b></td><td>5.45%</td></tr><tr><td><b>Sales</b></td><td>236.58B</td></tr><tr><td><b>P/S</b></td><td>13.32</td></tr><tr><td><b>EPS this Y</b></td><td>20.37%</td></tr><tr><td><b>Inst Trans</b></td><td>0.47%</td></tr><tr><td><b>Short Ratio</b></td><td>2.19</td></tr><tr><td><b>Perf Half Y</b></td><td>14.86%</td></tr><tr><td><b>Book/sh</b></td><td>34.06</td></tr><tr><td><b>P/B</b></td><td>12.45</td></tr><tr><td><b>EPS next Y Percentage</b></td><td>13.07%</td></tr><tr><td><b>ROA</b></td><td>19.94%</td></tr><tr><td><b>Short Interest</b></td><td>43.76M</td></tr><tr><td><b>Perf Year</b></td><td>26.22%</td></tr><tr><td><b>Cash/sh</b></td><td>10.77</td></tr><tr><td><b>P/C</b></td><td>39.38</td></tr><tr><td><b>EPS next 5Y</b></td><td>16.24%</td></tr><tr><td><b>ROE</b></td><td>38.49%</td></tr><tr><td><b>52W Range From</b></td><td>309.45</td></tr><tr><td><b>52W Range To</b></td><td>433.60</td></tr><tr><td><b>Perf YTD</b></td><td>12.76%</td></tr><tr><td><b>Dividend Est.</b></td><td>2.95 (0.70%)</td></tr><tr><td><b>P/FCF</b></td><td>44.65</td></tr><tr><td><b>EPS past 5Y</b></td><td>35.37%</td></tr><tr><td><b>ROI</b></td><td>26.01%</td></tr><tr><td><b>52W High</b></td><td>-2.21%</td></tr><tr><td><b>Beta</b></td><td>0.89</td></tr><tr><td><b>Dividend TTM</b></td><td>2.93 (0.69%)</td></tr><tr><td><b>Quick Ratio</b></td><td>1.23</td></tr><tr><td><b>Sales past 5Y</b></td><td>14.05%</td></tr><tr><td><b>Gross Margin</b></td><td>69.89%</td></tr><tr><td><b>52W Low</b></td><td>37.02%</td></tr><tr><td><b>ATR (14)</b></td><td>7.65</td></tr><tr><td><b>Dividend Ex-Date</b></td><td>May 15, 2024</td></tr><tr><td><b>Current Ratio</b></td><td>1.24</td></tr><tr><td><b>EPS Y/Y TTM</b></td><td>25.27%</td></tr><tr><td><b>Oper. Margin</b></td><td>44.70%</td></tr><tr><td><b>RSI (14)</b></td><td>55.41</td></tr><tr><td><b>Volatility W</b></td><td>2.16%</td></tr><tr><td><b>Volatility M</b></td><td>1.57%</td></tr><tr><td><b>Employees</b></td><td>221000</td></tr><tr><td><b>Debt/Eq</b></td><td>0.42</td></tr><tr><td><b>Sales Y/Y TTM</b></td><td>13.97%</td></tr><tr><td><b>Profit Margin</b></td><td>36.43%</td></tr><tr><td><b>Recom</b></td><td>1.25</td></tr><tr><td><b>Target Price</b></td><td>481.47</td></tr><tr><td><b>Option/Short</b></td><td>Yes / Yes</td></tr><tr><td><b>LT Debt/Eq</b></td><td>0.31</td></tr><tr><td><b>EPS Q/Q</b></td><td>19.77%</td></tr><tr><td><b>Payout</b></td><td>28.09%</td></tr><tr><td><b>Rel Volume</b></td><td>0.82</td></tr><tr><td><b>Prev Close</b></td><td>416.07</td></tr><tr><td><b>Sales Surprise</b></td><td>1.64%</td></tr><tr><td><b>EPS Surprise</b></td><td>4.25%</td></tr><tr><td><b>Sales Q/Q</b></td><td>17.03%</td></tr><tr><td><b>Earnings</b></td><td>Apr 25 AMC</td></tr><tr><td><b>Avg Volume</b></td><td>19.97M</td></tr><tr><td><b>Price</b></td><td>424.01</td></tr><tr><td><b>SMA20</b></td><td>0.93%</td></tr><tr><td><b>SMA50</b></td><td>1.96% ...
#
# </td></tr><tr><td><b>Volume</b></td><td>16,312,159</td></tr><tr><td><b>Change</b></td><td>1.91%</td></tr></table>

# %% [markdown]
# ## Collect Fundamental Info in DataFrame

# %%
df_stock_fundament = pd.DataFrame()
for ticker_to_analyze in tickers_to_analyze:
    stock = finvizfinance(ticker_to_analyze)
    new_row = pd.DataFrame([stock.ticker_fundament()])
    # Append the new row to the DataFrame
    df_stock_fundament = pd.concat([df_stock_fundament, new_row], ignore_index=True)

# df_stock_fundament = pd.DataFrame(stock_fundament, index=[0])
display(df_stock_fundament)
# Out:
#                          Company                  Sector  \
# 0          Microsoft Corporation              Technology
# 1                   Alphabet Inc  Communication Services
# 2  American Superconductor Corp.             Industrials
# 3        Boston Scientific Corp.              Healthcare
# 4                    Sea Ltd ADR       Consumer Cyclical
# 5                       RTX Corp             Industrials
# 6        Mastercard Incorporated               Financial
# 7      Palantir Technologies Inc              Technology
# 8          Uber Technologies Inc              Technology
# 9           United Rentals, Inc.             Industrials
#
#                          Industry    Country Exchange               Index  \
# 0       Software - Infrastructure        USA     NASD  DJIA, NDX, S&P 500
# 1  Internet Content & Information        USA     NASD        NDX, S&P 500
# 2  Specialty Industrial Machinery        USA     NASD                   -
# 3                 Medical Devices        USA     NYSE             S&P 500
# 4                 Internet Retail  Singapore     NYSE                   -
# 5             Aerospace & Defense        USA     NYSE             S&P 500
# 6                 Credit Services        USA     NYSE             S&P 500
# 7       Software - Infrastructure        USA     NYSE                   -
# 8          Software - Application        USA     NYSE             S&P 500
# 9       Rental & Leasing Services        USA     NYSE             S&P 500
#
#        P/E EPS (ttm) Insider Own Shs Outstand  ... Sales Q/Q    Earnings  \
# 0    36.74     11.54       1.47%        7.43B  ...    17.03%  Apr 25 AMC
# 1    27.16      6.52      57.75%        5.69B  ...    15.44%  Apr 25 AMC
# 2        -     -0.38       4.39%       36.95M  ...    32.40%  May 29 AMC
# 3    63.41      1.20       0.45%        1.47B  ...    13.78%  Apr 24 BMO
# 4  1896.80      0.04       1.88%      526.81M  ...    22.26%  May 14 BMO
# 5    42.54      2.55       0.10%        1.33B  ...    12.15%  Apr 23 BMO
# 6    35.50     12.58      11.00%      927.00M  ...    10.38%  May 01 BMO
# 7   181.22      0.13      14.46%        2.10B  ...    20.78%  May 06 AMC
# 8   102.73      0.64       3.94%        2.07B  ...    14.82%  May 08 BMO
# 9    17.35     36.94       0.51%       67.27M  ...     6.09%  Apr 24 AMC
#
#   Avg Volume   Price   SMA20   SMA50   SMA200 Trades      Volume  Change
# 0     19.97M  424.01   0.93%   1.96%   11.60%   \n\n  16,312,159   1.91%
# 1     21.10M  177.07   1.32%   7.09%   21.95%   \n\n  15,048,790   1.11%
# 2    521.78K   22.35  43.33%  61.72%  105.49%   \n\n   1,395,860   6.28%
# 3      6.16M   75.89   1.70%   6.10%   24.65%   \n\n   5,193,777  -0.04%
# 4      6.17M   71.13   2.87%  13.90%   50.77%   \n\n   3,669,076   1.50%
# 5      7.68M  108.44   2.70%   5.89%   23.13%   \n\n   3,122,676   0.50%
# 6      2.37M  446.66  -1.31%  -2.82%    3.30%   \n\n   2,030,072   0.42%
# 7     48.34M   22.96   7.61%   3.96%   18.33%   \n\n  39,526,976   3.89%
# 8     18.11M   65.82   0.58%  -5.91%    7.54%   \n\n  17,518,454   1.97%
# 9    524.18K  640.87  -5.31%  -5.57%   12.83%   \n\n     312,618   1.53%
#
# [10 rows x 85 columns]

# %% [markdown]
# ## Get all News

# %%
from finvizfinance.news import News

fnews = News()
all_news = fnews.get_news()
display(all_news['news'])
display(all_news['blogs'])

# %% [markdown]
# ## Insider Trades

# %%
from finvizfinance.insider import Insider

finsider = Insider(option='top owner trade')
# option: latest, top week, top owner trade
# default: latest
insider_trader = finsider.get_insider()

ticker_to_analyze = 'MA'
for ticker_to_analyze in tickers_to_analyze:
    if not insider_trader[insider_trader['Ticker']==ticker_to_analyze].empty:
        display(insider_trader[insider_trader['Ticker']==ticker_to_analyze])

display(insider_trader[insider_trader['Transaction']=='Buy'])

# display(insider_trader[insider_trader['Transaction']=='Sale'])
# Out:
#    Ticker                                    SEC Form 4 Link  \
# 9      MA  http://www.sec.gov/Archives/edgar/data/1141391...
# 10     MA  http://www.sec.gov/Archives/edgar/data/1141391...
# 11     MA  http://www.sec.gov/Archives/edgar/data/1141391...
# 12     MA  http://www.sec.gov/Archives/edgar/data/1141391...
# 13     MA  http://www.sec.gov/Archives/edgar/data/1141391...
#
#                     Owner Relationship    Date Transaction    Cost   #Shares  \
# 9   Mastercard Foundation    10% Owner  Jun 04        Sale  443.10  111000.0
# 10  Mastercard Foundation    10% Owner  May 29        Sale  443.44  110000.0
# 11  Mastercard Foundation    10% Owner  Jun 03        Sale  441.43  110000.0
# 12  Mastercard Foundation    10% Owner  May 30        Sale  442.70  104000.0
# 13  Mastercard Foundation    10% Owner  May 31        Sale  441.69  103000.0
#
#      Value ($)  #Shares Total       SEC Form 4
# 9   49184333.0     93903308.0  Jun 05 11:41 AM
# 10  48777982.0     94331308.0  May 30 09:09 AM
# 11  48556882.0     94014308.0  Jun 04 09:31 AM
# 12  46041268.0     94227308.0  May 31 11:23 AM
# 13  45494410.0     94124308.0  Jun 03 10:38 AM
#    Ticker                                    SEC Form 4 Link  \
# 27   ACDC  http://www.sec.gov/Archives/edgar/data/1641792...
# 29   CRGX  http://www.sec.gov/Archives/edgar/data/1253170...
# 30   ACDC  http://www.sec.gov/Archives/edgar/data/1641792...
#
#                          Owner Relationship    Date Transaction   Cost  \
# 27           THRC Holdings, LP    10% Owner  May 29         Buy   9.32
# 29  Samsara BioCapital GP, LLC    10% Owner  May 30         Buy  17.00
# 30           THRC Holdings, LP    10% Owner  May 28         Buy   9.49
#
#      #Shares  Value ($)  #Shares Total       SEC Form 4
# 27  559783.0  5217178.0     76200545.0  May 30 05:46 PM
# 29  294000.0  4998000.0      4415689.0  Jun 03 09:45 PM
# 30  440217.0  4177659.0     75640762.0  May 30 05:46 PM

# %% [markdown]
# ## SP500 Stocks

# %%
from finvizfinance.screener.overview import Overview
import warnings

# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

foverview = Overview()
filters_dict = {'Index':'S&P 500','Sector':'Basic Materials'}

filters_dict = {'Index':'S&P 500','Sector':'Any'}
foverview.set_filter(filters_dict=filters_dict)
df = foverview.screener_view()
df.head()
# Out:
# [Info] loading page [##############################] 26/26
#   Ticker                      Company             Sector  \
# 0      A    Agilent Technologies Inc.         Healthcare
# 1    AAL  American Airlines Group Inc        Industrials
# 2   AAPL                    Apple Inc         Technology
# 3   ABBV                   Abbvie Inc         Healthcare
# 4   ABNB                   Airbnb Inc  Consumer Cyclical
#
#                        Industry Country    Market Cap    P/E   Price  Change  \
# 0        Diagnostics & Research     USA  3.897000e+10  31.56  133.56  0.0207
# 1                      Airlines     USA  7.620000e+09  19.47   11.62  0.0104
# 2          Consumer Electronics     USA  3.003490e+12  30.46  195.87  0.0078
# 3  Drug Manufacturers - General     USA  2.921500e+11  49.26  165.44  0.0204
# 4               Travel Services     USA  9.255000e+10  19.53  145.78 -0.0088
#
#        Volume
# 0   2707455.0
# 1  34340912.0
# 2  54156784.0
# 3   5100491.0
# 4   3121512.0

# %% [markdown]
# ### SP500 Tickerlist

# %%
sp500_tickers = df['Ticker']

# %% [markdown]
# ### SP500 Winners

# %%
sp500_winners = df[df['Change']>0]
sp500_winners.sort_values(by='Change', ascending=False)
# Out:
#     Ticker                         Company           Sector  \
# 228    HPE   Hewlett Packard Enterprise Co       Technology
# 321   MRNA                     Moderna Inc       Healthcare
# 44    AVGO                    Broadcom Inc       Technology
# 330     MU          Micron Technology Inc.       Technology
# 288   LRCX              Lam Research Corp.       Technology
# ..     ...                             ...              ...
# 11     ADP  Automatic Data Processing Inc.      Industrials
# 235    HUM                     Humana Inc.       Healthcare
# 62      BK    Bank Of New York Mellon Corp        Financial
# 305    MET                     Metlife Inc        Financial
# 38     APD   Air Products & Chemicals Inc.  Basic Materials
#
#                                 Industry Country    Market Cap    P/E  \
# 228              Communication Equipment     USA  2.532000e+10  14.20
# 321                        Biotechnology     USA  5.934000e+10    NaN
# 44                        Semiconductors     USA  6.548500e+11  52.38
# 330                       Semiconductors     USA  1.480700e+11    NaN
# 288  Semiconductor Equipment & Materials     USA  1.270400e+11  35.73
# ..                                   ...     ...           ...    ...
# 11        Staffing & Employment Services     USA  1.006000e+11  27.44
# 235                     Healthcare Plans     USA  4.350000e+10  22.47
# 62                      Asset Management     USA  4.404000e+10  14.33
# 305                     Insurance - Life     USA  5.001000e+10  24.17
# 38                   Specialty Chemicals     USA  6.010000e+10  24.46
#
#        Price  Change      Volume
# 228    19.48  0.1068  88344873.0
# 321   154.84  0.0654   4038109.0
# 44   1413.09  0.0618   3287544.0
# 330   133.71  0.0558  20899590.0
# 288   971.72  0.0531   1164015.0
# ..       ...     ...         ...
# 11    245.78  0.0004   1298307.0
# 235   361.00  0.0004   1053711.0
# 62     58.89  0.0003   2282870.0
# 305    70.33  0.0003   2205963.0
# 38    270.33  0.0001    804050.0
#
# [322 rows x 10 columns]

# %% [markdown]
# ## Filters

# %%
from finvizfinance.screener.overview import Overview

foverview = Overview()
filters = foverview.get_filters()

for filter in filters:
    print(filter)
# Out:
# Exchange
# Index
# Sector
# Industry
# Country
# Market Cap.
# P/E
# Forward P/E
# PEG
# P/S
# P/B
# Price/Cash
# Price/Free Cash Flow
# EPS growththis year
# EPS growthnext year
# EPS growthpast 5 years
# EPS growthnext 5 years
# Sales growthpast 5 years
# EPS growthqtr over qtr
# Sales growthqtr over qtr
# Dividend Yield
# Return on Assets
# Return on Equity
# Return on Investment
# Current Ratio
# Quick Ratio
# LT Debt/Equity
# Debt/Equity
# Gross Margin
# Operating Margin
# Net Profit Margin
# Payout Ratio
# InsiderOwnership
# InsiderTransactions
# InstitutionalOwnership
# InstitutionalTransactions
# Float Short
# Analyst Recom.
# Option/Short
# Earnings Date
# Performance
# Performance 2
# Volatility
# RSI (14)
# Gap
# 20-Day Simple Moving Average
# 50-Day Simple Moving Average
# 200-Day Simple Moving Average
# Change
# Change from Open
# 20-Day High/Low
# 50-Day High/Low
# 52-Week High/Low
# Pattern
# Candlestick
# Beta
# Average True Range
# Average Volume
# Relative Volume
# Current Volume
# Price
# Target Price
# IPO Date
# Shares Outstanding
# Float

# %% [markdown]
# ## Screener Fundamental and Technical

# %%
from finvizfinance.screener.overview import Overview
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

def Universe(filter):
    
    foverview = Overview()
    
    foverview.set_filter(filters_dict=filter)
    df = foverview.screener_view()
    return df


filter = {
'Index': 'S&P 500', 
'200-Day Simple Moving Average': 'SMA200 below SMA50',
'50-Day Simple Moving Average': 'SMA50 below SMA20',
'20-Day Simple Moving Average': 'Price above SMA20',
'EPS growththis year': 'Positive (>0%)',
'EPS growthnext year': 'Positive (>0%)',
'EPS growthqtr over qtr': 'Positive (>0%)',
'Beta': 'Any',
'Net Profit Margin': 'Positive (>0%)',
'Debt/Equity': 'Low (<0.1)'
}

universe = Universe(filter)
display(universe)
# Out:
# [Info] loading page [##############################] 1/1
#   Ticker                       Company                  Sector  \
# 0   FSLR               First Solar Inc              Technology
# 1   GOOG                  Alphabet Inc  Communication Services
# 2  GOOGL                  Alphabet Inc  Communication Services
# 3   ISRG        Intuitive Surgical Inc              Healthcare
# 4   SNPS                Synopsys, Inc.              Technology
# 5   VRTX  Vertex Pharmaceuticals, Inc.              Healthcare
#
#                          Industry Country    Market Cap    P/E   Price  \
# 0                           Solar     USA  2.959000e+10  28.99  276.47
# 1  Internet Content & Information     USA  2.198120e+12  27.28  177.87
# 2  Internet Content & Information     USA  2.180690e+12  27.06  176.46
# 3  Medical Instruments & Supplies     USA  1.467900e+11  74.67  413.84
# 4       Software - Infrastructure     USA  8.902000e+10  63.21  581.00
# 5                   Biotechnology     USA  1.244200e+11  31.28  482.15
#
#    Change     Volume
# 0  0.0125   811017.0
# 1  0.0045  4409872.0
# 2  0.0060  5367914.0
# 3 -0.0081   373844.0
# 4 -0.0121   259814.0
# 5 -0.0018   203032.0
